# %%
import numpy as np 
import pandas as pd 

import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
from collections import Counter

# %%
stop_words = stopwords.words('english')

sample_text="Oh man, this is pretty cool. 22 We will do more such things."

# %%
word_tok =word_tokenize(sample_text.lower())

# %%
print(word_tok)
# Out:
# ['oh', 'man', ',', 'this', 'is', 'pretty', 'cool', '.', '22', 'we', 'will', 'do', 'more', 'such', 'things', '.']

# %%
words_without_punk = [w for w in word_tok if w.isalpha()]

# %%
words_without_punk
# Out:
# ['oh',
#  'man',
#  'this',
#  'is',
#  'pretty',
#  'cool',
#  'we',
#  'will',
#  'do',
#  'more',
#  'such',
#  'things']

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /Users/aydin/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
words_without_punk = [t for t in words_without_punk if t not in stop_words]

# %%
st = PorterStemmer()

# %%
lem = WordNetLemmatizer()

# %%
[lem.lemmatize(t) for t in words_without_punk]
# Out:
# ['oh', 'man', 'pretty', 'cool', 'thing']

# %%
[st.stem(t) for t in words_without_punk]
# Out:
# ['oh', 'man', 'pretti', 'cool', 'thing']

# %%
f = open("/Users/aydin/Downloads/data.txt", "r", encoding='latin-1')
text = f.read()

# %%
text[:1000]
# Out:
# "The Project Gutenberg EBook of Man to Man, by Jackson Gregory\n\nThis eBook is for the use of anyone anywhere at no cost and with\nalmost no restrictions whatsoever.  You may copy it, give it away or\nre-use it under the terms of the Project Gutenberg License included\nwith this eBook or online at www.gutenberg.org\n\n\nTitle: Man to Man\n\nAuthor: Jackson Gregory\n\nRelease Date: July 29, 2006 [EBook #18933]\n\nLanguage: English\n\n\n*** START OF THIS PROJECT GUTENBERG EBOOK MAN TO MAN ***\n\n\n\n\nProduced by Al Haines\n\n\n\n\n\n\n\n\n\n\n[Frontispiece: The blazing heat was such that men and horses and steers\nsuffered terribly.]\n\n\n\n\n\n\nMAN TO MAN\n\n\nBY\n\nJACKSON GREGORY\n\n\n\nAUTHOR OF\n\nJUDITH OF BLUE LAKE RANCH, THE BELLS OF SAN JUAN, SIX FEET FOUR, ETC.\n\n\n\n\nILLUSTRATED BY\n\nJ. G. SHEPHERD\n\n\n\n\n\nGROSSET & DUNLAP\n\nPUBLISHERS -------- NEW YORK\n\n\n\n\nCOPYRIGHT, 1920, BY\n\nCHARLES SCRIBNER'S SONS\n\n\nPublished October, 1920\n\n\n\n\nCONTENTS\n\n\nCHAPT
# ...

# %%
sentece = sent_tokenize(text.lower())

# %%
len(sentece)
# Out:
# 5551

# %%
corpus =[]
for i in sentece:
    sent = word_tokenize(i)
    corpus.append(sent)

# %%
# Out:
# [['the',
#   'project',
#   'gutenberg',
#   'ebook',
#   'of',
#   'man',
#   'to',
#   'man',
#   ',',
#   'by',
#   'jackson',
#   'gregory',
#   'this',
#   'ebook',
#   'is',
#   'for',
#   'the',
#   'use',
#   'of',
#   'anyone',
#   'anywhere',
#   'at',
#   'no',
#   'cost',
#   'and',
#   'with',
#   'almost',
#   'no',
#   'restrictions',
#   'whatsoever',
#   '.'],
#  ['you',
#   'may',
#   'copy',
#   'it',
#   ',',
#   'give',
#   'it',
#   'away',
#   'or',
#   're-use',
#   'it',
#   'under',
#   'the',
#   'terms',
#   'of',
#   'the',
#   'project',
#   'gutenberg',
#   'license',
#   'included',
#   'with',
#   'this',
#   'ebook',
#   'or',
#   'online',
#   'at',
#   'www.gutenberg.org',
#   'title',
#   ':',
#   'man',
#   'to',
#   'man',
#   'author',
#   ':',
#   'jackson',
#   'gregory',
#   'release',
#   'date',
#   ':',
#   'july',
#   '29',
#   ',',
#   '2006',
#   '[',
#   'ebook',
#   '#',
#   '18933',
#   ']',
#   'language',
#   ':',
#   'english',
# ...

# %%
corpus = word_tokenize(text.lower())

# %%
len(corpus)
# Out:
# 97042

# %%
corpus_alt = text.lower().split()

# %%
len(corpus_alt)
# Out:
# 78078

# %%
corpus_1 = [w for w in corpus if w.isalpha()]

# %%
len(corpus_1)
# Out:
# 77105

# %%
corpus_2 = [t for t in corpus_1 if t not in stop_words]

# %%
len(corpus_2)
# Out:
# 38117

# %%
coprus_lem = [lem.lemmatize(t) for t in corpus_2]

# %%
coprus_st = [st.stem(t) for t in corpus_2]

# %%
print(Counter(coprus_lem).most_common(10))
# Out:
# [('steve', 542), ('packard', 541), ('blenham', 524), ('man', 445), ('terry', 409), ('said', 307), ('little', 291), ('old', 284), ('eye', 261), ('know', 224)]

# %%
original = " ".join(coprus_lem)

# %%
nltk.download("averaged_perceptron_tagger")
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/aydin/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
text="Steven Paul Jobs (/dʒɒbz/; February 24, 1955 – October 5, 2011) was an American business magnate, industrial designer, investor, and media proprietor. He was the chairman, chief executive officer (CEO), and co-founder of Apple Inc., the chairman and majority shareholder of Pixar, a member of The Walt Disney Company's board of directors following its acquisition of Pixar, and the founder, chairman, and CEO of NeXT. Jobs is widely recognized as a pioneer of the personal computer revolution of the 1970s and 1980s, along with Apple co-founder Steve Wozniak."

# %%
text_tokens=nltk.word_tokenize(text.lower())
tokens_without_punc = [w for w in text_tokens if w.isalpha()]
tokens_without_sw = [t for t in tokens_without_punc if t not in stop_words]
text_cleaned = [lem.lemmatize(t) for t in tokens_without_sw]

# %%
original=' '.join(text_cleaned)
original
# Out:
# 'steven paul job february october american business magnate industrial designer investor medium proprietor chairman chief executive officer ceo apple chairman majority shareholder pixar member walt disney company board director following acquisition pixar founder chairman ceo next job widely recognized pioneer personal computer revolution along apple steve wozniak'

# %%
tagged = nltk.pos_tag(text_cleaned)

# %%
tagged
# Out:
# [('steven', 'NN'),
#  ('paul', 'NNS'),
#  ('job', 'NN'),
#  ('february', 'JJ'),
#  ('october', 'JJ'),
#  ('american', 'JJ'),
#  ('business', 'NN'),
#  ('magnate', 'NN'),
#  ('industrial', 'JJ'),
#  ('designer', 'NN'),
#  ('investor', 'NN'),
#  ('medium', 'NN'),
#  ('proprietor', 'NN'),
#  ('chairman', 'NN'),
#  ('chief', 'JJ'),
#  ('executive', 'JJ'),
#  ('officer', 'NN'),
#  ('ceo', 'NN'),
#  ('apple', 'NN'),
#  ('chairman', 'NN'),
#  ('majority', 'NN'),
#  ('shareholder', 'NN'),
#  ('pixar', 'NN'),
#  ('member', 'NN'),
#  ('walt', 'NN'),
#  ('disney', 'NN'),
#  ('company', 'NN'),
#  ('board', 'NN'),
#  ('director', 'NN'),
#  ('following', 'VBG'),
#  ('acquisition', 'NN'),
#  ('pixar', 'FW'),
#  ('founder', 'NN'),
#  ('chairman', 'NN'),
#  ('ceo', 'VBP'),
#  ('next', 'JJ'),
#  ('job', 'NN'),
#  ('widely', 'RB'),
#  ('recognized', 'VBN'),
#  ('pioneer', 'NN'),
#  ('personal', 'JJ'),
#  ('computer', 'NN'),
#  ('revolution', 'NN'),
#  ('along', 'IN'),
#  ('apple', 'NN'),
# ...

# %%
nltk.download('maxent_ne_chunker')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /Users/aydin/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker.zip.
# True

# %%
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to /Users/aydin/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# True

# %%
pip install ghostscript
# Out:
# ...
# WARNING: You are using pip version 20.3.1; however, version 20.3.3 is available.
# You should consider upgrading via the '/Users/aydin/opt/anaconda3/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
brew install ghostscript
# Out:
#   File "<ipython-input-427-26b1a8d9f630>", line 1
#     brew install ghostscript
#                ^
# SyntaxError: invalid syntax

# %%
name = nltk.ne_chunk(tagged)

# %%
name.draw()

# %%
from wordcloud import WordCloud

# %%
wordcloud = WordCloud(max_words=5000)

# %%
wordcloud.generate(original)

# %%
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
stop_words = stopwords.words('german')

# %%
stop_words
# Out:
# ['acaba',
#  'ama',
#  'aslında',
#  'az',
#  'bazı',
#  'belki',
#  'biri',
#  'birkaç',
#  'birşey',
#  'biz',
#  'bu',
#  'çok',
#  'çünkü',
#  'da',
#  'daha',
#  'de',
#  'defa',
#  'diye',
#  'eğer',
#  'en',
#  'gibi',
#  'hem',
#  'hep',
#  'hepsi',
#  'her',
#  'hiç',
#  'için',
#  'ile',
#  'ise',
#  'kez',
#  'ki',
#  'kim',
#  'mı',
#  'mu',
#  'mü',
#  'nasıl',
#  'ne',
#  'neden',
#  'nerde',
#  'nerede',
#  'nereye',
#  'niçin',
#  'niye',
#  'o',
#  'sanki',
#  'şey',
#  'siz',
#  'şu',
#  'tüm',
#  've',
#  'veya',
#  'ya',
#  'yani']

# %%
from bs4 import BeautifulSoup

# %%
#url = "https://www.nytimes.com"
#url = 'https://www.washingtonpost.com'
url='https://www.zeit.de/index'
html = urlopen(url).read()
soup = BeautifulSoup(html)

for script in soup(["script", "style"]):
    script.decompose()


strips = list(soup.stripped_strings)
print(strips[:5])
# Out:
# ['ZEIT ONLINE | Nachrichten, Hintergründe und Debatten', 'Zum Inhalt springen', 'Lesezeichen', 'ZEIT ONLINE', 'Schwerpunkte']

# %%
text = " ".join(strips)

# %%
text_tokens=nltk.word_tokenize(text.lower())
tokens_without_punc = [w for w in text_tokens if w.isalpha()]
tokens_without_sw = [t for t in tokens_without_punc if t not in stop_words]
text_cleaned = [lem.lemmatize(t) for t in tokens_without_sw]

# %%
original = " ".join(text_cleaned)

# %%
wordcloud.generate(original)

# %%
plt.figure(figsize=(20,20))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('The Washington Post', fontdict={'fontsize': 25})
# Out:
# Text(0.5, 1.0, 'The Washington Post')

# %%
import requests
import lxml.html as lh
import pandas as pd

# %%
URL='https://meta.wikimedia.org/wiki/List_of_Wikipedias'
#Create a handle, page, to handle the contents of the website
tables = pd.read_html(URL,match="Performance details")
print("There are : ",len(tables)," tables")
print("Take look at table 0")
tables[0]

# %%
df = pd.DataFrame()
URL = "https://meta.wikimedia.org/wiki/List_of_Wikipedias"
tables = pd.read_html(URL,match="Admins")
print("There are : ",len(tables)," tables")
print("Take look at table 0")
df = pd.concat([i for i in tables], ignore_index=True)
# Out:
# There are :  9  tables
# Take look at table 0

# %%
df.head()
# Out:
#      № Language       Language (local) Wiki Articles     Total      Edits  \
# 0  1.0  English                English   en  6211509  52172083  990573574
# 1  2.0  Cebuano  Sinugboanong Binisaya  ceb  5437264   9985010   30243612
# 2  3.0  Swedish                Svenska   sv  3498188   7537803   48486969
# 3  4.0   German                Deutsch   de  2512692   7001055  205303324
# 4  5.0   French               Français   fr  2279553  11078751  177366717
#
#   Admins     Users  Active Users   Files Depth
# 0   1119  40554362      132118.0  892712  1040
# 1      6     74007         157.0       0     2
# 2     61    754651        2575.0       0     9
# 3    190   3599762       19124.0  129906    94
# 4    159   3962287       21013.0   62974   239

# %%
df.Language.value_counts()
# Out:
# Sichuan Yi     1
# Papiamentu     1
# Tswana         1
# Mazandarani    1
# Mingrelian     1
#               ..
# Polish         1
# Aragonese      1
# Asturian       1
# Serbian        1
# Quechua        1
# Name: Language, Length: 314, dtype: int64

# %%
hdi
# Out:
#     rank chane                   country  score avg_growth_2010-2019
# 0      1   NaN                    Norway  0.957                0.20%
# 1      2   (7)                   Ireland  0.955                0.65%
# 2      2   NaN               Switzerland  0.955                0.16%
# 3      4   (7)                 Hong Kong  0.949                0.54%
# 4      4   (4)                   Iceland  0.949                0.62%
# ..   ...   ...                       ...    ...                  ...
# 187  185   (5)                   Burundi  0.433                0.58%
# 188  185   (3)               South Sudan  0.433                0.61%
# 189  187   (1)                      Chad  0.398                0.84%
# 190  188   (1)  Central African Republic  0.397                0.94%
# 191  189   (1)                     Niger  0.394                1.95%
#
# [192 rows x 5 columns]

# %%
URL = "https://www.cia.gov/library/publications/the-world-factbook/fields/402.html"
tables = pd.read_html(URL)
print("There are : ",len(tables)," ")
print("Take look at table 0")
lan = tables[0]
# Out:
# There are :  1
# Take look at table 0

# %%
lan_git = pd.DataFrame(my_dict).T

# %%
lan_git.to_csv('lang_git')

# %%
lan_git
# Out:
#                     name                         native phone continent  \
# AD               Andorra                        Andorra   376        EU
# AE  United Arab Emirates  دولة الإمارات العربية المتحدة   971        AS
# AF           Afghanistan                      افغانستان    93        AS
# AG   Antigua and Barbuda            Antigua and Barbuda  1268        NA
# AI              Anguilla                       Anguilla  1264        NA
# ..                   ...                            ...   ...       ...
# YE                 Yemen                        اليَمَن   967        AS
# YT               Mayotte                        Mayotte   262        AF
# ZA          South Africa                   South Africa    27        AF
# ZM                Zambia                         Zambia   260        AF
# ZW              Zimbabwe                       Zimbabwe   263        AF
#
#              capital                         currency  \
# ...

# %%
lan_git['first_languge']=lan_git.languages.apply(lambda x: x[0])

# %%
wiki_cnt= pd.merge(lan_git, df, right_on='Wiki', left_on='first_languge')

# %%
wiki_cnt
# Out:
#                      name                         native phone continent  \
# 0                 Andorra                        Andorra   376        EU
# 1    United Arab Emirates  دولة الإمارات العربية المتحدة   971        AS
# 2                 Bahrain                       ‏البحرين   973        AS
# 3                 Algeria                        الجزائر   213        AF
# 4                   Egypt                           مصر‎    20        AF
# ..                    ...                            ...   ...       ...
# 244            Uzbekistan                    O‘zbekiston   998        AS
# 245               Vietnam                       Việt Nam    84        AS
# 246               Vanuatu                        Vanuatu   678        OC
# 247                 Samoa                          Samoa   685        OC
# 248          South Africa                   South Africa    27        AF
#
#               capital currency                                 languages  \
# ...

# %%
last = pd.merge(wiki_cnt, pop, right_on='country.value', left_on='name')

# %%
pop=pd.read_csv('/Users/aydin/GIT/world_bank_works/world_bank_first_project')[['country.value','Population, total', 'year']]

# %%
last['Articles']= last['Articles'].astype('int')

# %%
last[['Total','Edits', 'Admins','Users']]= last[['Total','Edits', 'Admins','Users']].astype('int')

# %%
wiki_cnt
# Out:
#                      name                         native phone continent  \
# 0                 Andorra                        Andorra   376        EU
# 1    United Arab Emirates  دولة الإمارات العربية المتحدة   971        AS
# 2                 Bahrain                       ‏البحرين   973        AS
# 3                 Algeria                        الجزائر   213        AF
# 4                   Egypt                           مصر‎    20        AF
# ..                    ...                            ...   ...       ...
# 244            Uzbekistan                    O‘zbekiston   998        AS
# 245               Vietnam                       Việt Nam    84        AS
# 246               Vanuatu                        Vanuatu   678        OC
# 247                 Samoa                          Samoa   685        OC
# 248          South Africa                   South Africa    27        AF
#
#               capital currency                                 languages  \
# ...

# %%
last
# Out:
#                      name                         native phone continent  \
# 0                 Andorra                        Andorra   376        EU
# 1    United Arab Emirates  دولة الإمارات العربية المتحدة   971        AS
# 2                 Bahrain                       ‏البحرين   973        AS
# 3                 Algeria                        الجزائر   213        AF
# 4                    Iraq                         العراق   964        AS
# ..                    ...                            ...   ...       ...
# 179            Uzbekistan                    O‘zbekiston   998        AS
# 180               Vietnam                       Việt Nam    84        AS
# 181               Vanuatu                        Vanuatu   678        OC
# 182                 Samoa                          Samoa   685        OC
# 183          South Africa                   South Africa    27        AF
#
#               capital currency                                 languages  \
# ...

# %%
 df_wiki = last.groupby('Language').mean()[['Articles','Total','Edits','Admins','Users','Active Users']]

# %%
df_wiki
# Out:
#             Articles     Total     Edits  Admins    Users  Active Users
# Language
# Afrikaans      95273    346759   2348657      18   130344         191.0
# Albanian       81856    243292   2164065      13   128240         318.0
# Amharic        14905     45650    361599       3    33443          43.0
# Arabic       1095518   7056318  51929641      26  1971883        5945.0
# Armenian      279159    943480   7565118      11   105000         673.0
# ...              ...       ...       ...     ...      ...           ...
# Turkish       384480   1917333  24386044      26  1249280        3424.0
# Turkmen         5851     14006    214548       1    20676          44.0
# Ukrainian    1062376   3647991  30262775      47   536467        3525.0
# Uzbek         139174    632172   2154849      11    58106         356.0
# Vietnamese   1259848  19217219  64106237      20   778662        2045.0
#
# [67 rows x 6 columns]

# %%
df_wiki['pop_total']=last.groupby('Language').sum()[['Population, total']]

# %%
df_wiki
# Out:
#             Articles     Total     Edits  Admins    Users  Active Users  \
# Language
# Afrikaans      95273    346759   2348657      18   130344         191.0
# Albanian       81856    243292   2164065      13   128240         318.0
# Amharic        14905     45650    361599       3    33443          43.0
# Arabic       1095518   7056318  51929641      26  1971883        5945.0
# Armenian      279159    943480   7565118      11   105000         673.0
# ...              ...       ...       ...     ...      ...           ...
# Turkish       384480   1917333  24386044      26  1249280        3424.0
# Turkmen         5851     14006    214548       1    20676          44.0
# Ukrainian    1062376   3647991  30262775      47   536467        3525.0
# Uzbek         139174    632172   2154849      11    58106         356.0
# Vietnamese   1259848  19217219  64106237      20   778662        2045.0
#
#               pop_total  ratio_total
# Language
# Afrikaans    58558270.0     0.005922
# ...

# %%
df_wiki['ratio_total']= df_wiki['Total']/df_wiki['pop_total']

# %%
df_wiki['ratio_Articles']= df_wiki['Articles']/df_wiki['pop_total']
df_wiki['ratio_Edits']= df_wiki['Edits']/df_wiki['pop_total']
df_wiki['ratio_Admins']= df_wiki['Admins']/df_wiki['pop_total']
df_wiki['ratio_Users']= df_wiki['Users']/df_wiki['pop_total']
df_wiki['ratio_Active_Users']= df_wiki['Active Users']/df_wiki['pop_total']

# %%
df_wiki_ratio = df_wiki[['ratio_total','ratio_Articles','ratio_Edits','ratio_Admins','ratio_Users','ratio_Active_Users']]

# %%
df_wiki_ratio.sort_values('ratio_Articles', ascending=False).head(50)
# Out:
#                     ratio_total  ratio_Articles  ratio_Edits  ratio_Admins  \
# Language
# Catalan               21.310013        8.638057   333.014700  2.851884e-04
# Swedish                0.732861        0.340110     4.714131  5.930706e-06
# Faroese                0.813612        0.276408     7.430708  8.217264e-05
# Estonian               0.385200        0.161438     4.349141  2.487581e-05
# Icelandic              0.371813        0.141952     4.678830  8.026282e-05
# Norwegian (Bokmål)     0.279794        0.102233     3.919799  6.918609e-06
# Armenian               0.318988        0.094383     2.557744  3.719067e-06
# Finnish                0.239988        0.090419     3.509149  5.977921e-06
# Serbian                0.520042        0.084734     3.100995  2.643016e-06
# Slovenian              0.197404        0.081691     2.586559  1.005773e-05
# Lithuanian             0.172218        0.072073     2.161449  4.664775e-06
# ...

# %%
df_wiki_ratio.sort_values('ratio_Users', ascending=False).head(50)
# Out:
#                     ratio_total  ratio_Articles  ratio_Edits  ratio_Admins  \
# Language
# Catalan               21.310013        8.638057   333.014700  2.851884e-04
# Faroese                0.813612        0.276408     7.430708  8.217264e-05
# Icelandic              0.371813        0.141952     4.678830  8.026282e-05
# Greenlandic            0.051152        0.014406     1.310342  3.557137e-05
# Estonian               0.385200        0.161438     4.349141  2.487581e-05
# Norwegian (Bokmål)     0.279794        0.102233     3.919799  6.918609e-06
# Slovenian              0.197404        0.081691     2.586559  1.005773e-05
# Finnish                0.239988        0.090419     3.509149  5.977921e-06
# Hebrew                 0.131508        0.031321     3.323517  3.976451e-06
# Swedish                0.732861        0.340110     4.714131  5.930706e-06
# Danish                 0.148804        0.045314     1.808107  4.296601e-06
# ...

# %%
ca=pd.merge(last, hdi,left_on='name', right_on='country')

# %%
ca['score']=ca.score.astype('float')

# %%
ca['rank']=ca['rank'].astype('int')

# %%
ca.groupby('Language').mean()
# Out:
#                 №   Articles       Total       Edits  Admins      Users  \
# Language
# Afrikaans    70.0    95273.0    346759.0   2348657.0    18.0   130344.0
# Albanian     75.0    81856.0    243292.0   2164065.0    13.0   128240.0
# Amharic     128.0    14905.0     45650.0    361599.0     3.0    33443.0
# Arabic       16.0  1095518.0   7056318.0  51929641.0    26.0  1971883.0
# Armenian     37.0   279159.0    943480.0   7565118.0    11.0   105000.0
# ...           ...        ...         ...         ...     ...        ...
# Turkish      31.0   384480.0   1917333.0  24386044.0    26.0  1249280.0
# Turkmen     183.0     5851.0     14006.0    214548.0     1.0    20676.0
# Ukrainian    17.0  1062376.0   3647991.0  30262775.0    47.0   536467.0
# Uzbek        59.0   139174.0    632172.0   2154849.0    11.0    58106.0
# Vietnamese   12.0  1259848.0  19217219.0  64106237.0    20.0   778662.0
#
#             Active Users  Population, total    year     rank     score
# Language
# ...

# %%
# Out:
#                           №  Articles     Total     Edits    Admins     Users  \
# №                  1.000000 -0.488535 -0.405217 -0.383691 -0.357399 -0.364265
# Articles          -0.488535  1.000000  0.980403  0.979603  0.969848  0.967611
# Total             -0.405217  0.980403  1.000000  0.995749  0.992918  0.992922
# Edits             -0.383691  0.979603  0.995749  1.000000  0.997873  0.996904
# Admins            -0.357399  0.969848  0.992918  0.997873  1.000000  0.995546
# Users             -0.364265  0.967611  0.992922  0.996904  0.995546  1.000000
# Active Users      -0.374368  0.975109  0.995149  0.999470  0.997927  0.998397
# Population, total -0.016786 -0.056201 -0.041452 -0.047005 -0.039825 -0.039017
# year                    NaN       NaN       NaN       NaN       NaN       NaN
# rank               0.085690  0.167873  0.186638  0.169393  0.161842  0.162324
# score             -0.069053 -0.166986 -0.178348 -0.162729 -0.155500 -0.151808
#
# ...
