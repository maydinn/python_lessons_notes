# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
diamonds=sns.load_dataset('diamonds')
exercise=sns.load_dataset('exercise')
flights=sns.load_dataset('flights')
geyser=sns.load_dataset('geyser')
iris=sns.load_dataset('iris')
penguins=sns.load_dataset('penguins')
planets=sns.load_dataset('planets')
mpg=sns.load_dataset('mpg')
tips = sns.load_dataset('tips')
titanic=sns.load_dataset('titanic')

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
sns.distplot(penguins['body_mass_g'])

# %%
penguins.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
sns.distplot(penguins['body_mass_g'], hist_kws=dict(edgecolor='k', lw=1))

# %%
sns.distplot(penguins['body_mass_g'], hist_kws=dict(edgecolor='k', lw=1), kde = False)

# %%
penguins.dropna(inplace=True)

# %%
penguins.isnull().sum()
# Out:
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64

# %%
sns.distplot(penguins['body_mass_g'], hist_kws=dict(edgecolor='k', lw=1), kde = False)

# %%
sns.distplot(penguins['body_mass_g'], hist_kws=dict(edgecolor='k', lw=1), kde = False, bins=30)

# %%
sns.set(style="white", palette="muted", color_codes=True)

# Set up the matplotlib figure
f, axes = plt.subplots(2, 2, figsize=(7, 7), sharex=True)
sns.despine(left=True)

# Generate a random univariate dataset
d = penguins['body_mass_g']

# Plot a simple histogram with binsize determined automatically
sns.distplot(d, kde=False, color="b", ax=axes[0, 0])

# Plot a kernel density estimate and rug plot
sns.distplot(d, hist=False, rug=True, color="r", ax=axes[0, 1])

# Plot a filled kernel density estimate
sns.distplot(d, hist=False, color="g", kde_kws={"shade": True}, ax=axes[1, 0])

# Plot a histogram and kernel density estimate
sns.distplot(d, color="m", ax=axes[1, 1])

plt.setp(axes, yticks=[])
plt.tight_layout()

# %%
geyser.head()
# Out:
#    duration  waiting   kind
# 0     3.600       79   long
# 1     1.800       54  short
# 2     3.333       74   long
# 3     2.283       62  short
# 4     4.533       85   long

# %%
sns.distplot(geyser['waiting'], kde=False)

# %%
geyser.waiting.mean()
# Out:
# 70.8970588235294

# %%
sns.distplot(tips['total_bill'], kde = False)

# %%
sns.jointplot(tips['total_bill'], tips['tip'], kind="hex", height=7, space=0)

# %%
sns.jointplot(tips['total_bill'], tips['tip'], kind="scatter", height=7, space=0)

# %%
tips.groupby(['day']).corr()
# Out:
#                  total_bill       tip      size
# day
# Thur total_bill    1.000000  0.812406  0.700123
#      tip           0.812406  1.000000  0.646094
#      size          0.700123  0.646094  1.000000
# Fri  total_bill    1.000000  0.771934  0.630475
#      tip           0.771934  1.000000  0.487166
#      size          0.630475  0.487166  1.000000
# Sat  total_bill    1.000000  0.703632  0.584187
#      tip           0.703632  1.000000  0.416737
#      size          0.584187  0.416737  1.000000
# Sun  total_bill    1.000000  0.501753  0.537981
#      tip           0.501753  1.000000  0.450840
#      size          0.537981  0.450840  1.000000

# %%
sns.scatterplot(tips['total_bill'], tips['tip'], hue ='sex', data=tips)

# %%
tips[['total_bill', 'tip', 'sex']].groupby(['sex']).describe()
# Out:
#        total_bill                                                         \
#             count       mean       std   min    25%    50%    75%    max
# sex
# Male        157.0  20.744076  9.246469  7.25  14.00  18.35  24.71  50.81
# Female       87.0  18.056897  8.009209  3.07  12.75  16.40  21.52  44.30
#
#           tip
#         count      mean       std  min  25%   50%   75%   max
# sex
# Male    157.0  3.089618  1.489102  1.0  2.0  3.00  3.76  10.0
# Female   87.0  2.833448  1.159495  1.0  2.0  2.75  3.50   6.5

# %%
tips[['total_bill', 'tip', 'sex']].groupby(['sex']).boxplot()
# Out:
# Male           AxesSubplot(0.1,0.15;0.363636x0.75)
# Female    AxesSubplot(0.536364,0.15;0.363636x0.75)
# dtype: object

# %%
sns.pairplot(data= mpg)

# %%
sns.distplot(mpg.model_year, bins=10)

# %%
mpg[['mpg', 'model_year']].groupby(['model_year']).mean()
# Out:
#                   mpg
# model_year
# 70          17.689655
# 71          21.250000
# 72          18.714286
# 73          17.100000
# 74          22.703704
# 75          20.266667
# 76          21.573529
# 77          23.375000
# 78          24.061111
# 79          25.093103
# 80          33.696552
# 81          30.334483
# 82          31.709677

# %%
mpg[['mpg', 'model_year']].groupby(['model_year']).mean().plot()

# %%
mpg[['horsepower', 'origin']].groupby(['origin']).mean()
# Out:
#         horsepower
# origin
# europe   80.558824
# japan    79.835443
# usa     119.048980

# %%
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
sns.scatterplot(x= 'mpg', y= 'horsepower', data= mpg, hue = 'origin')

# %%
-sns.scatterplot(x= 'cylinders', y= 'horsepower', data= mpg, hue = 'origin')

# %%
sns.distplot(mpg.groupby(['origin'])['model_year'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-06cb773ecbba> in <module>
# ----> 1 sns.distplot(mpg.groupby(['origin'])['model_year'])
#
# ~/opt/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     177
#     178     # Make a a 1-d float array
# --> 179     a = np.asarray(a, np.float)
#     180     if a.ndim > 1:
#     181         a = a.squeeze()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ValueError: could not convert string to float: 'europe'

# %%
sns.scatterplot(x= 'model_year', y= 'horsepower', data=mpg, hue= 'origin')

# %%
sns.barplot(x='model_year', )

# %%
df = mpg.groupby(['model_year', 'origin']).count()[['horsepower']]
df = df.reset_index()

# %%
sns.barplot('model_year', 'horsepower', data = df, hue = 'origin')

# %%
labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]
df = pd.DataFrame(list(zip(labels, men_means, women_means)), columns =["labels", "men_means", "women_means"])
df.head()
# Out:
#   labels  men_means  women_means
# 0     G1         20           25
# 1     G2         34           32
# 2     G3         30           34
# 3     G4         35           20
# 4     G5         27           25

# %%
sns.barplot(df['labels'], df['men_means'])

# %%
sns.barplot('labels', 'men_means', data=df)

# %%
sns.barplot('labels', 'men_means', data=df, 
            order= df.sort_values('men_means').labels)

# %%
df.sort_values('men_means')
# Out:
#   labels  men_means  women_means
# 0     G1         20           25
# 4     G5         27           25
# 2     G3         30           34
# 1     G2         34           32
# 3     G4         35           20

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.barplot('sex', 'total_bill', data=tips)

# %%
sns.barplot('sex', 'total_bill', ci=None,data=tips)

# %%
sns.barplot('sex', 'total_bill', hue='smoker',data=tips)

# %%
sns.barplot('day', 'tip', hue='sex',data=tips)

# %%
sns.barplot('sex', 'tip', hue='day',data=tips)

# %%
sns.barplot('day', 'tip',data=tips)

# %%
sns.barplot(x="cylinders",y="horsepower", data=mpg)

# %%
sns.barplot(x="sex", y="age", hue = "class",data=titanic)

# %%
sns.countplot(x='sex', data=tips)

# %%
tips.sex.value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
tips.sex.value_counts().plot.bar()

# %%
sns.countplot(x="model_year", data=mpg)

# %%
sns.countplot(x="origin", data=mpg)

# %%
fig, ax = plt.subplots()
sns.countplot(x="origin", hue = 'model_year', ax=ax, data=mpg)
ax.plot(label=mpg['model_year'])
ax.legend()

# %%
sns.boxplot('day', 'total_bill', hue='smoker', data=tips)

# %%
sns.boxplot('origin', 'horsepower', data=mpg)

# %%
titanic.groupby(['sex','class']).mean()
# Out:
#                survived  pclass        age     sibsp     parch        fare  \
# sex    class
# female First   0.968085     1.0  34.611765  0.553191  0.457447  106.125798
#        Second  0.921053     2.0  28.722973  0.486842  0.605263   21.970121
#        Third   0.500000     3.0  21.750000  0.895833  0.798611   16.118810
# male   First   0.368852     1.0  41.281386  0.311475  0.278689   67.226127
#        Second  0.157407     2.0  30.740707  0.342593  0.222222   19.741782
#        Third   0.135447     3.0  26.507589  0.498559  0.224784   12.661633
#
#                adult_male     alone
# sex    class
# female First     0.000000  0.361702
#        Second    0.000000  0.421053
#        Third     0.000000  0.416667
# male   First     0.975410  0.614754
#        Second    0.916667  0.666667
#        Third     0.919308  0.760807

# %%
sns.swarmplot('class', 'age', hue='survived', data = titanic)
plt.legend()

# %%
sns.swarmplot('origin', 'horsepower', hue='cylinders', data = mpg)
plt.legend()

# %%
sns.catplot('origin', 'horsepower', hue='cylinders', data = mpg, kind='bar')

# %%
sns.pointplot('time', 'total_bill', data=tips)

# %%
sns.distplot(penguins.body_mass_g)

# %%
sns.heatmap(tips.corr(), annot=True).  'Weight', 'Drive chain', 'prev_owner'

# %%
flights.pivot_table(columns='year', values='passengers', index='month')
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
# November    104   114   146   172   180   203   237   271   305   310   362
# ...

# %%
sns.heatmap(flights.pivot_table(columns='year', values='passengers', index='month'))

# %%
sns.heatmap(flights.pivot_table(columns='year', values='passengers', index='month'), linecolor='white', lw=0.2)

# %%
sns.heatmap(mpg.corr(), annot=True)

# %%
fig = plt.subplots(figsize=(12,10))
sns.heatmap(mpg.corr(), annot=True)

# %%
sns.pairplot(tips, hue='sex')

# %%
sns.pairplot(tips, kind='reg')

# %%
g=sns.PairGrid(tips)
g.map_diag(plt.hist)
g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot)

# %%
g=sns.FacetGrid(tips, col='day', row='time')
g.map(plt.hist, 'total_bill')

# %%
g=sns.FacetGrid(tips, col='time', row='smoker')
g.map(plt.hist, 'total_bill')

# %%
sns.lmplot('total_bill', 'tip', tips)

# %%
sns.lmplot('total_bill', 'tip', tips, ci=99)

# %%
sns.lmplot('total_bill', 'tip', tips, ci=70)

# %%
sns.lmplot('total_bill', 'tip', tips, col='sex')

# %%
sns.lmplot('total_bill', 'tip', tips, col='sex', row='time')

# %%
sns.lmplot('total_bill', 'tip', tips, col='sex', row='time', aspect=3, height=6)

# %%
sns.set_style('dark')
sns.countplot('sex', data=tips)

# %%
sns.set_style('whitegrid')
sns.countplot('sex', data=tips)

# %%
sns.set_style('darkgrid')
sns.countplot('sex', data=tips)

# %%
plt.style.use('ggplot')
sns.countplot('sex', data=tips)

# %%
sns.set_style('white')
sns.countplot('sex', data=tips)
sns.despine()

# %%
plt.style.use('default')
sns.set_style('white')
sns.countplot('sex', data=tips)
sns.despine(left=True, bottom=True)

# %%
x= ['JavaScript',
 'HTML/CSS',
 'SQL',
 'Python',
 'Java',
 'Bash/Shel/PS',
 'C#',
 'PHP',
 'C++',
 'TypeScript',
 'C',
 'Other(s):',
 'Ruby',
 'Go',
 'Assembly']

y=[59219,
 55466,
 47544,
 36443,
 35917,
 31991,
 27097,
 23030,
 20524,
 18523,
 18017,
 7920,
 7331,
 7201,
 5833]

fig, ax = plt.subplots(figsize=(15, 7))
sns.set_context('notebook')
sns.barplot(x,y, palette='plasma')
ax.set_title("Most Popular Languages")
ax.set_ylabel('Number of People Who Use')
ax.set_xticklabels(x, rotation=45);

# %%
sns.set_context('')
sns.countplot('sex', data=tips)

# %%
df = pd.read_csv('cleaned_autos.csv')

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#            dateCrawled                            name  seller offerType  \
# 0  2016-03-24 11:52:17                      Golf_3_1.6  privat     Offer
# 1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  privat     Offer
# 2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  privat     Offer
# 3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER  privat     Offer
# 4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  privat     Offer
#
#    price abtest vehicleType  yearOfRegistration    gearbox  powerPS  model  \
# 0    480   test       Other                1993    manuell        0   golf
# 1  18300   test       coupe                2011    manuell      190  Other
# 2   9800   test         suv                2004  automatik      163  grand
# 3   1500   test  kleinwagen                2001    manuell       75   golf
# 4   3600   test  kleinwagen                2008    manuell       69  fabia
#
#    kilometer monthOfRegistration  fuelType       brand notRepairedDamage  \
# ...

# %%
df.shape
# Out:
# (313687, 27)

# %%
df.vehicleType.unique()
# Out:
# array(['Other', 'coupe', 'suv', 'kleinwagen', 'limousine', 'cabrio',
#        'kombi', 'bus', 'andere'], dtype=object)

# %%
sns.barplot('vehicleType', 'price', data=df)

# %%
sns.boxplot('vehicleType', 'price', data=df)

# %%
df.groupby('vehicleType')['price'].describe()
# Out:
#                count          mean          std  min     25%     50%      75%  \
# vehicleType
# Other        19447.0    861.466447   910.077425  0.0   150.0   550.0   1250.0
# andere        2908.0   2400.906465  2073.032544  0.0   750.0  1800.0   3699.0
# bus          26833.0   4677.360601  3347.835853  0.0  1999.0  3900.0   6770.0
# cabrio       20388.0   6934.699382  5258.656445  0.0  2799.0  5500.0   9999.0
# coupe        16920.0   6741.053960  6396.913719  0.0  1600.0  4250.0  10900.0
# kleinwagen   69334.0   1730.123085  1412.804402  0.0   650.0  1290.0   2500.0
# kombi        60195.0   3961.032129  3366.369561  0.0  1250.0  2850.0   5999.0
# limousine    84077.0   3745.179122  3203.717790  0.0  1200.0  2650.0   5700.0
# suv          13585.0  10772.809349  7095.459271  0.0  4900.0  9800.0  15555.0
#
#                  max
# vehicleType
# Other         3700.0
# andere        8350.0
# bus          13900.0
# cabrio       21400.0
# coupe        24299.0
# kleinwagen    5765.0
# ...

# %%
sns.pointplot(x="vehicleType", y="price", data=df)

# %%
g=sns.FacetGrid(df, col='vehicleType')
g.map(plt.hist, 'price')

# %%
sns.countplot('vehicleType', data = df, order=df['vehicleType'].value_counts().index)

# %%
df.vehicleType.value_counts().plot.bar()

# %%
mpg.corr()
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.775396     -0.804203   -0.778427 -0.831741
# cylinders    -0.775396   1.000000      0.950721    0.842983  0.896017
# displacement -0.804203   0.950721      1.000000    0.897257  0.932824
# horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# weight       -0.831741   0.896017      0.932824    0.864538  1.000000
# acceleration  0.420289  -0.505419     -0.543684   -0.689196 -0.417457
# model_year    0.579267  -0.348746     -0.370164   -0.416361 -0.306564
#
#               acceleration  model_year
# mpg               0.420289    0.579267
# cylinders        -0.505419   -0.348746
# displacement     -0.543684   -0.370164
# horsepower       -0.689196   -0.416361
# weight           -0.417457   -0.306564
# acceleration      1.000000    0.288137
# model_year        0.288137    1.000000

# %%
sns.barplot('cylinders', '')
# Out:
# 3

# %%
mpg.groupby('displacement').mean()
# Out:
#                     mpg  cylinders  horsepower       weight  acceleration  \
# displacement
# 68.0          29.000000        4.0   49.000000  1867.000000     19.500000
# 70.0          20.233333        3.0   95.666667  2291.333333     13.166667
# 71.0          31.500000        4.0   65.000000  1804.500000     20.000000
# 72.0          35.000000        4.0   69.000000  1613.000000     18.000000
# 76.0          31.000000        4.0   52.000000  1649.000000     16.500000
# ...                 ...        ...         ...          ...           ...
# 400.0         13.961538        8.0  174.769231  4521.230769     11.715385
# 429.0         12.666667        8.0  201.333333  4642.000000     10.833333
# 440.0         13.500000        8.0  215.000000  4523.500000      9.750000
# 454.0         14.000000        8.0  220.000000  4354.000000      9.000000
# 455.0         13.333333        8.0  225.000000  4154.000000     10.333333
#
#               model_year
# displacement
# ...

# %%
df1=pd.read_csv('df1')

# %%
df2=pd.read_csv('df2')

# %%
df1.head()
# Out:
#    Unnamed: 0         A         B         C         D
# 0  2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 1  2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2  2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 3  2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 4  2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
sns.set_style(style='darkgrid')

# %%
df = pd.DataFrame({'sales': [3, 2, 3, 9, 10, 6], 'signups': [5, 5, 6, 12, 14, 13],
                   'visits': [20, 42, 28, 62, 81, 50]},
                  index=pd.date_range(start='2018/01/01', end='2018/07/01',
                                      freq='M'))
df.head()
# Out:
#             sales  signups  visits
# 2018-01-31      3        5      20
# 2018-02-28      2        5      42
# 2018-03-31      3        6      28
# 2018-04-30      9       12      62
# 2018-05-31     10       14      81

# %%
df.plot.area()

# %%
df.plot(kind='area')

# %%
df.plot.bar()

# %%
speed = [0.1, 17.5, 40, 48, 52, 69, 88]
lifespan = [2, 8, 70, 1.5, 25, 12, 28]
index = ['snail', 'pig', 'elephant','rabbit', 'giraffe', 'coyote', 'horse']
df = pd.DataFrame({'speed': speed,'lifespan': lifespan}, index=index)
df.head()
# Out:
#           speed  lifespan
# snail       0.1       2.0
# pig        17.5       8.0
# elephant   40.0      70.0
# rabbit     48.0       1.5
# giraffe    52.0      25.0

# %%
df.plot.bar()

# %%
df.plot.bar()
plt.axhline(y=50, ls="--")

# %%
g= df.plot.bar()
g.set_ylabel('speed/lifespan')
g.set_title('speed/lifespan per animal')
g.set_xticklabels(df.index, rotation=45);
g.axhline(y=50, ls="--")

# %%
income = [100, 80, 150, 48, 52, 69, 88]
expense = [30, 100, 100, 20, 75, 50, 28]
index = ['snail', 'pig', 'elephant','rabbit', 'giraffe', 'coyote', 'horse']
df = pd.DataFrame({'income': income,'expense': expense}, index=index)
df.head()
# Out:
#           income  expense
# snail        100       30
# pig           80      100
# elephant     150      100
# rabbit        48       20
# giraffe       52       75

# %%
df.plot.bar(stacked=True)

# %%
df['profit_lose'] = df.income -df.expense

# %%
df
# Out:
#           income  expense  profit_lose
# snail        100       30           70
# pig           80      100          -20
# elephant     150      100           50
# rabbit        48       20           28
# giraffe       52       75          -23
# coyote        69       50           19
# horse         88       28           60

# %%
mpg.horsepower.plot.hist(bins=20)

# %%
df1.B.plot()

# %%
mpg.groupby(['model_year']).mean()['horsepower'].plot()

# %%
mpg[['horsepower', 'cylinders']].corr()
# Out:
#             horsepower  cylinders
# horsepower    1.000000   0.842983
# cylinders     0.842983   1.000000

# %%
mpg.groupby(['model_year']).mean()['mpg'].plot(ls="--")
mpg.groupby(['model_year']).mean()['horsepower'].plot(secondary_y=True)

# %%
from pandas_datareader import data
from datetime import datetime
start = datetime(2020, 1, 1)
end = datetime(2020, 8, 30)

# %%
f = data.DataReader(name="AAPL", data_source="av-daily", start=start, end=end, api_key = "CI1UUA44YI12JAB3")

# %%
f.index = pd.to_datetime(f.index)
f.close.plot()

# %%
seven = f.close.rolling(window=7).mean()

# %%
seven.head(10)
# Out:
# 2020-01-02           NaN
# 2020-01-03           NaN
# 2020-01-06           NaN
# 2020-01-07           NaN
# 2020-01-08           NaN
# 2020-01-09           NaN
# 2020-01-10    302.731429
# 2020-01-13    305.104286
# 2020-01-14    307.282857
# 2020-01-15    308.931429
# Name: close, dtype: float64

# %%
ten = f.close.rolling(window=10).mean()

# %%
ten.head(15)
# Out:
# 2020-01-02        NaN
# 2020-01-03        NaN
# 2020-01-06        NaN
# 2020-01-07        NaN
# 2020-01-08        NaN
# 2020-01-09        NaN
# 2020-01-10        NaN
# 2020-01-13        NaN
# 2020-01-14        NaN
# 2020-01-15    306.010
# 2020-01-16    307.499
# 2020-01-17    309.629
# 2020-01-21    311.306
# 2020-01-22    313.237
# 2020-01-23    314.841
# Name: close, dtype: float64

# %%
f.close.plot()
ten.plot()

# %%
mpg.plot.scatter('mpg', 'weight', c='horsepower', cmap='coolwarm')

# %%
mpg.boxplot(column='horsepower', by='origin')
