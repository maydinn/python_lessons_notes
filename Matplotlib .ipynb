# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
age = [25, 27, 29, 31, 33, 35, 37, 39, 41, 43, 45]
salary = [38496, 42000, 46752, 49320, 53200,
         56000, 62316, 64928, 67317, 68748, 73752]

# %%
plt.plot(age, salary)
plt.xlabel = ('age')
plt.ylabel =('salary')
plt.title =('salary by age')
plt.show()

# %%
salary_2 = [45372, 48876, 53850, 57287, 63016,
            65998, 70003, 70000, 71496, 75370, 83640]

# %%
plt.plot(age, salary)
plt.plot(age, salary_2)
plt.xlabel = ('age')
plt.ylabel =('salary')
plt.title =('salary by age')
plt.show()

# %%
plt.plot(age, salary, label ='salary1')
plt.plot(age, salary_2, label ='salary2')
plt.xlabel = ('age')
plt.ylabel =('salary')
plt.title =('salary by age')
plt.legend()

# %%
plt.subplot(2,1,1)
plt.plot(age, salary,'r' ,label ='salary1',)
plt.subplot(2,1,2)
plt.plot(age, salary_2,'b', label ='salary2')
plt.legend()

# %%
plt.subplot(2,2,1)
plt.plot(age, salary,'r' ,label ='salary1',)
plt.subplot(2,2,2)
plt.plot(age, salary_2,'b', label ='salary2')
plt.subplot(2,2,3)
plt.plot(age, salary_2,'b', label ='salary2')
plt.subplot(2,2,4)
plt.plot(age, salary_2,'b', label ='salary2')

# %%
plt.plot(salary)

# %%
import pandas as pd
df = pd.DataFrame(list(zip(age, salary, salary_2)), columns =['age', 'salary', 'salary_2'])
df.head()
# Out:
#    age  salary  salary_2
# 0   25   38496     45372
# 1   27   42000     48876
# 2   29   46752     53850
# 3   31   49320     57287
# 4   33   53200     63016

# %%
plt.plot(df['age'], df['salary'])

# %%
fig = plt.figure()
axes =fig.add_axes([0.1,0.1,0.8,0.8])

# %%
fig = plt.figure()
axes =fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(age, salary,'r')

# %%
fig = plt.figure()
ax =fig.add_axes([0.1,0.1,0.8,0.8])
ax1 =fig.add_axes([0.2,0.6,0.2,0.2])

ax.plot(age, salary,'r')
ax.set_title('salary1')
ax1.plot(age, salary_2, 'b')
ax1.set_title('salary2')
# Out:
# Text(0.5, 1.0, 'salary2')

# %%
fig, ax = plt.subplots()
ax.plot(age, salary, 'r')

# %%
fig, ax = plt.subplots(nrows=2, ncols=1)
ax[0].plot(age, salary, 'r')
ax[1].plot(age, salary_2, 'b')

# %%
fig, ax = plt.subplots(nrows=1, ncols=2)
ax[0].plot(age, salary, 'r')
ax[0].set_xlabel('age')
ax[0].set_ylabel('salary')
ax[0].set_title('salary by age')
ax[1].plot(age, salary_2, 'b')
ax[1].set_xlabel('age')
ax[1].set_ylabel('salary')
ax[1].set_title('salary by age')
plt.tight_layout()

# %%
fig

# %%
ax
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fd9ab531150>,
# ...
#       dtype=object)

# %%
fig, ax = plt.subplots(nrows=2, ncols=2)

# %%
fig, ax = plt.subplots(nrows=2, ncols=2)
ax[0,0].plot(age, salary, 'r')
ax[0,0].set_xlabel('age')
ax[0,0].set_ylabel('salary')
ax[0,0].set_title('salary by age')
ax[1,0].plot(age, salary_2, 'b')
ax[1,0].set_xlabel('age')
ax[1,0].set_ylabel('salary')
ax[1,0].set_title('salary by age')
ax[0,1].plot(age, salary, 'r')
ax[0,1].set_xlabel('age')
ax[0,1].set_ylabel('salary')
ax[0,1].set_title('salary by age')
ax[1,1].plot(age, salary_2, 'b')
ax[1,1].set_xlabel('age')
ax[1,1].set_ylabel('salary')
ax[1,1].set_title('salary by age')
plt.tight_layout()

# %%
df = pd.DataFrame(list(zip(age, salary, salary_2)), columns=['age', 'salar', 'salary_2'])

# %%
df
# Out:
#     age  salar  salary_2
# 0    25  38496     45372
# 1    27  42000     48876
# 2    29  46752     53850
# 3    31  49320     57287
# 4    33  53200     63016
# 5    35  56000     65998
# 6    37  62316     70003
# 7    39  64928     70000
# 8    41  67317     71496
# 9    43  68748     75370
# 10   45  73752     83640

# %%
fig, ax = plt.subplots(figsize=(6,3))
ax.plot(age, salary, 'r')
ax.set_xlabel('age')
ax.set_ylabel('salary')
ax.set_title('title');

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(6,3))
ax[0].plot(age, salary)
ax[0].set_xlabel('age')
ax[1].plot(age, salary_2)
ax[0].set_title('First')
ax[1].set_title('Second')
ax[1].set_xlabel('age')
plt.tight_layout()

# %%
fig.savefig('myplot.png')

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(8,4))
ax[0].plot(age, salary, label ='salary', color= 'g', lw=3, ls='--', marker="o", alpha=0.3)
ax[0].set_xlabel('age')
ax[1].plot(age, salary_2, label = 'salary_2', color = 'r', lw=2, ls = "-.", marker="*", alpha= 0.7)
ax[0].set_title('First')
ax[1].set_title('Second')
ax[1].set_xlabel('age')
ax[0].legend()
ax[1].legend()
plt.tight_layout()

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(8,4))
ax[0].plot(age, salary, label ='salary', color= 'g', lw=3, ls='--', marker="o", alpha=0.3)
ax[0].set_xlabel('age')
ax[1].plot(age, salary_2, label = 'salary_2', color = 'r', lw=2, ls = "-.", marker="*", alpha= 0.7)
ax[0].set_title('First')
ax[1].set_title('Second')
ax[1].set_xlabel('age')
ax[0].set_xlim([30,40])
ax[0].legend()
ax[1].legend()
plt.tight_layout()

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(8,4))
ax[0].plot(age, salary, label ='salary', color= 'g', lw=3, ls='--', marker="o", alpha=0.3)
ax[0].set_xlabel('age')
ax[1].plot(age, salary_2, label = 'salary_2', color = 'r', lw=2, ls = "-.", marker="*", alpha= 0.7)
ax[0].set_title('First')
ax[1].set_title('Second')
ax[1].set_xlabel('age')
ax[0].axvline(x=35, ls="--")
ax[1].axhline(y=70000, ls="--")
ax[0].legend()
ax[1].legend()
plt.tight_layout()

# %%
country = ['UK', 'USA', 'FRA', 'GER', 'NOR']
pic = [40000, 50000, 38000, 55000, 80000]

# %%
fig, ax = plt.subplots()
ax.bar(country, pic)
# Out:
# <BarContainer object of 5 artists>

# %%
labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

# %%
fig, ax = plt.subplots()
ax.bar(labels, men_means, alpha=0.5, width = 0.4)
ax.bar(labels, women_means, alpha=1, width = 0.2)
# Out:
# <BarContainer object of 5 artists>

# %%
import numpy as np
x = np.arange(len(labels))  # the label locations
width = 0.35
fig, ax = plt.subplots()
ax.bar(x - width/2, men_means, width, label='Men')
ax.bar(x + width/2, women_means, width, label='Women')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

# %%
fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label='Men')
rects2 = ax.bar(x + width/2, women_means, width, label='Women')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

plt.show()

# %%
type(ax)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
df = pd.DataFrame(list(zip(labels, men_means, women_means)), columns =["labels", "men", "women"])
df.head()
# Out:
#   labels  men  women
# 0     G1   20     25
# 1     G2   34     32
# 2     G3   30     34
# 3     G4   35     20
# 4     G5   27     25

# %%
ax = df.plot.bar()
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()
for p in ax.patches:
    ax.annotate((p.get_height()), (p.get_x()+0.05, p.get_height()+0.25))

# %%
ax = df.plot.bar()
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticklabels(labels)
ax.axhline(y=20, color='r', ls="--")

for p in ax.patches:
    ax.annotate((p.get_height()), (p.get_x()+0.05, p.get_height()+0.25))

# %%
ax = df.plot.bar(x='labels',stacked=True)
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticklabels(labels)


plt.show()

# %%
df.plot.barh(x='labels',stacked=True)

# %%
df_bar = pd.read_csv('bar_data.csv')

# %%
df_bar.head()
# Out:
#    Responder_id                          LanguagesWorkedWith
# 0             1              HTML/CSS;Java;JavaScript;Python
# 1             2                          C++;HTML/CSS;Python
# 2             3                                     HTML/CSS
# 3             4                          C;C++;C#;Python;SQL
# 4             5  C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA

# %%
my_list =[]

for i in df_bar['LanguagesWorkedWith']:
    a = i.split(";")
    for j in a:
        my_list.append(j)

# %%
seri = pd.Series(my_list)

# %%
seri.value_counts()
# Out:
# JavaScript               59219
# HTML/CSS                 55466
# SQL                      47544
# Python                   36443
# Java                     35917
# Bash/Shell/PowerShell    31991
# C#                       27097
# PHP                      23030
# C++                      20524
# TypeScript               18523
# C                        18017
# Other(s):                 7920
# Ruby                      7331
# Go                        7201
# Assembly                  5833
# Swift                     5744
# Kotlin                    5620
# R                         5048
# VBA                       4781
# Objective-C               4191
# Scala                     3309
# Rust                      2794
# Dart                      1683
# Elixir                    1260
# Clojure                   1254
# WebAssembly               1015
# F#                         973
# Erlang                     777
# dtype: int64

# %%
df_g_g = df_g_g.reset_index()

# %%
df_g_g.drop(1, axis=1,inplace=True)

# %%
df_g = pd.DataFrame(seri)

# %%
df_g['programing language'] = [i for i in range(1, len(my_list)+1)]

# %%
df_g_g = df_g.groupby(0).count()

# %%
df_g_g = df_g_g.sort_values(by = 'programing language')

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(12,10))
ax.barh(df_g_g[0], df_g_g['programing language'])
ax.set_ylabel('')
ax.set_title('most popular languages')
ax.axvline(x=30000, color = 'r', ls = '--')
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(pad=1.08, h_pad=None, w_pad=None, rect=None)>

# %%
age = [25, 27, 29, 31, 33, 35, 37, 39, 41, 43, 45]
salary = [38496, 42000, 46752, 49320, 53200,
         56000, 62316, 64928, 67317, 68748, 73752]

# %%
plt.plot(age, salary, label = 'salar1')
plt.plot(age, salary_2, label = 'salar2')
plt.xlabel('age')
plt.ylabel('salary')
plt.title('salary by age')
plt.legend()

# %%
plt.subplot(2,1,1)
plt.plot(age, salary, label = 'salar1')
plt.subplot(2,1,2)
plt.plot(age, salary, label = 'salar2')
plt.tight_layout()

# %%
plt.subplot(1,2,1)
plt.plot(age, salary,color='r', label = 'salar1')
plt.subplot(1,2,2)
plt.plot(age, salary, label = 'salar2')
plt.tight_layout()

# %%
plt.subplot(2,2,1)
plt.plot(age, salary,color='r', label = 'salar1')
plt.subplot(2,2,2)
plt.plot(age, salary, label = 'salar2')
plt.tight_layout()
plt.subplot(2,2,3)
plt.plot(age, salary,color='r', label = 'salar1')
plt.subplot(2,2,4)
plt.plot(age, salary, label = 'salar2')
plt.tight_layout()

# %%
from mpl_toolkits import mplot3d
